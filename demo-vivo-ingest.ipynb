# %% [markdown]
# #VIVO ingest with Python
#
# VIVO 1.6 ontology VCard usage: https://wiki.duraspace.org/display/VIVO/VCard+usage+diagram
#
#
# ###Tools/requirements
#  * [RDFLib](https://rdflib.readthedocs.org/en/latest/)
#
#
# ##Faculty
# A common scenario is that a VIVO implementation team will receive an export data from a system of record in CSV or TSV format.
#
# For demonstration purposes, lets take the first 5 rows of the CSV file that contains faculty data.

# %%
# !head -n 5 data/person_tamu.csv
# Out:
# UID,NETID,ORCID,FullName,FirstName,LastName,MidName,Email,Phone,Fax,Title
# 2dec06e9,Sadav,,"Sadav, Manjit S.",Manjit,Sadav,S,Sadav@tamu.edu,,,Professor
# c81ef444,mindyGergman,,"Gergman, Mindy E.",Mindy,Gergman,E,mindyGergman@tamu.edu,,,Associate Professor
# 5c2cef0e,t_Vay,,"Vay, Matilda W.",Matilda,Vay,W,t_Vay@tamu.edu,,,Lecturer
# b6f25071,sBach,,"Bach, Susan A.",Susan,Bach,A,sBach@tamu.edu,,,Clinical Associate Professor

# %%
# !head -n 5 data/person_tamu.csv > data/sample_person.csv

# %% [markdown]
# ###Read the CSV file of sample data
#
# The read_file function is a reusable block of code that strips empty cells and any line breaks that might appear in the CSV file.  You will probably develop your own similar routine for cleaning CSV data as you become familiar with the types of data problems or inconsistencies that arise from your sources.

# %%
from utils import read_file
from pprint import pprint

data = read_file('data/sample_person.csv')
pprint(data)
# Out:
# [{'Email': u'Sadav@tamu.edu',
#   'Fax': None,
#   'FirstName': u'Manjit',
#   'FullName': u'Sadav, Manjit S.',
#   'LastName': u'Sadav',
#   'MidName': u'S',
#   'NETID': u'Sadav',
#   'ORCID': None,
#   'Phone': None,
#   'Title': u'Professor',
#   'UID': u'2dec06e9'},
#  {'Email': u'mindyGergman@tamu.edu',
#   'Fax': None,
#   'FirstName': u'Mindy',
#   'FullName': u'Gergman, Mindy E.',
#   'LastName': u'Gergman',
#   'MidName': u'E',
#   'NETID': u'mindyGergman',
#   'ORCID': None,
#   'Phone': None,
#   'Title': u'Associate Professor',
#   'UID': u'c81ef444'},
#  {'Email': u't_Vay@tamu.edu',
#   'Fax': None,
#   'FirstName': u'Matilda',
#   'FullName': u'Vay, Matilda W.',
#   'LastName': u'Vay',
#   'MidName': u'W',
#   'NETID': u't_Vay',
#   'ORCID': None,
#   'Phone': None,
#   'Title': u'Lecturer',
#   'UID': u'5c2cef0e'},
#  {'Email': u'sBach@tamu.edu',
#   'Fax': None,
#   'FirstName': u'Susan',
#   'FullName': u'Bach, Susan A.',
#   'LastName': u'Bach',
#   'MidName': u'A',
#   'NETID': u'sBach',
#   'ORCID': None,
#   'Phone': None,
#   'Title': u'Clinical Associate Professor',
#   'UID': u'b6f25071'}]

# %% [markdown]
# ###Create RDF
#
# Iterate through the CSV data.  Create a URI for each faculty member from the UID and an rdfs:label.

# %%
from rdflib import Graph, Namespace, URIRef, Literal, RDF, RDFS

#Our data namespace
D = Namespace('http://vivo.school.edu/individual/')
#The VIVO namespace
VIVO = Namespace('http://vivoweb.org/ontology/core#')

#Create an RDFLib Graph
g = Graph()

for row in data:
    id = row['UID']
    #Make a uri
    uri = D['fac{}'.format(id)]
    #type
    g.add((uri, RDF.type, VIVO.FacultyMember))
    #label
    g.add((uri, RDFS.label, Literal(row['FullName'])))
#print as turtle
print g.serialize(format='turtle')
# Out:
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://vivo.brown.edu/individual/fac2dec06e9> a <http://vivoweb.org/ontology/core#FacultyMember> ;
#     rdfs:label "Sadav, Manjit S." .
#
# <http://vivo.brown.edu/individual/fac5c2cef0e> a <http://vivoweb.org/ontology/core#FacultyMember> ;
#     rdfs:label "Vay, Matilda W." .
#
# <http://vivo.brown.edu/individual/facb6f25071> a <http://vivoweb.org/ontology/core#FacultyMember> ;
#     rdfs:label "Bach, Susan A." .
#
# <http://vivo.brown.edu/individual/facc81ef444> a <http://vivoweb.org/ontology/core#FacultyMember> ;
#     rdfs:label "Gergman, Mindy E." .

# %% [markdown]
# A URI and a rdfs:label is the minimal amount of data need to create an entity in VIVO.  After loading this into VIVO you will be able to browse the entities using the VIVO interface and can use the interface to make additional assertions.
#
# ###Add the data to VIVO
#
# ####via the interface
# ![Add remove](./files/add_remove_rdf.png)

# %% [markdown]
# ####via the SPARQL Update API
# The VIVO SPARQL Update API allows you to write data back to VIVO using the W3C [SPARQL 1.1](http://www.w3.org/TR/sparql11-query/).  This was added to VIVO in version 1.6.
#
# Included in this sample code is a utility for writing RDFLib graphs to a VIVO 1.6 instance using the update API.

# %%
from utils import VUpdate
vstore = VUpdate()
vstore.add(g)

# %% [markdown]
# ##Organizations
#
# Ingesting organizational units from a CSV would follow a similar path.
#
# Make a sample file.

# %%
organizations = read_file('data/organizations.csv')
pprint(organizations[0:5])
# Out:
# [{'org_ID': u'8b9df681',
#   'org_name': u'Accounting',
#   'org_vivo_uri': u'http://vivoweb.org/ontology/core#Department'},
#  {'org_ID': u'e5c84f0a',
#   'org_name': u'Aerospace Engineering',
#   'org_vivo_uri': u'http://vivoweb.org/ontology/core#Department'},
#  {'org_ID': u'2d953da5',
#   'org_name': u'Agriculture Leadership Education and Communication',
#   'org_vivo_uri': u'http://vivoweb.org/ontology/core#Department'},
#  {'org_ID': u'2735b399',
#   'org_name': u'Animal Science',
#   'org_vivo_uri': u'http://vivoweb.org/ontology/core#Department'},
#  {'org_ID': u'26ddd99c',
#   'org_name': u'Anthropology',
#   'org_vivo_uri': u'http://vivoweb.org/ontology/core#Department'}]

# %% [markdown]
# You can see that the organization data is slightly different.  There is a name, an identifier, but also someone has assigned a VIVO class type to each row.  We can use Python to convert that string into a URI.  With actual data, you might have a string type, such as "Center" or "School" that you would then need to map to a class type from an ontology.

# %%
#Create a new empty graph for the organizations.
g = Graph()

for item in organizations:
    org_uri = D['org{}'.format(item['org_ID'])]
    org_type = URIRef(item['org_vivo_uri'])
    g.add( (org_uri, RDF.type, org_type) )
    g.add( (org_uri, RDFS.label, Literal(item['org_name'])) )

print g.serialize(format='turtle')
# Out:
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://vivo.brown.edu/individual/org1b23429b> a <http://vivoweb.org/ontology/core#College> ;
#     rdfs:label "College of Engineering" .
#
# <http://vivo.brown.edu/individual/org1b945f59> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Petroleum Engineering" .
#
# <http://vivo.brown.edu/individual/org1ec41847> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Mechanical Engineering" .
#
# <http://vivo.brown.edu/individual/org21aae1c6> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Veterinary Integrative Biosciences" .
#
# <http://vivo.brown.edu/individual/org224add21> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Horticultural Science" .
#
# <http://vivo.brown.edu/individual/org26ddd99c> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Anthropology" .
#
# <http://vivo.brown.edu/individual/org2735b399> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Animal Science" .
#
# <http://vivo.brown.edu/individual/org2833755e> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Atmospheric Sciences" .
#
# <http://vivo.brown.edu/individual/org2872677a> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Ecosystem Science and Management" .
#
# <http://vivo.brown.edu/individual/org2884689f> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Biological and Agricultural Engineering" .
#
# <http://vivo.brown.edu/individual/org2d222064> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Entomology" .
#
# <http://vivo.brown.edu/individual/org2d633240> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Electrical and Computer Engineering" .
#
# <http://vivo.brown.edu/individual/org2d953da5> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Agriculture Leadership Education and Communication" .
#
# <http://vivo.brown.edu/individual/org329894a2> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Veterinary Pathobiology" .
#
# <http://vivo.brown.edu/individual/org331ec525> a <http://vivoweb.org/ontology/core#College> ;
#     rdfs:label "Bush School of Government and Public Service" .
#
# <http://vivo.brown.edu/individual/org364e823b> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Educational Psychology" .
#
# <http://vivo.brown.edu/individual/org377fce7d> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Mathematics" .
#
# <http://vivo.brown.edu/individual/org38381a9e> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Veterinary Physiology and Pharmacology" .
#
# <http://vivo.brown.edu/individual/org390956d8> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Management" .
#
# <http://vivo.brown.edu/individual/org3c372a44> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Architecture" .
#
# <http://vivo.brown.edu/individual/org3d066602> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Chemistry" .
#
# <http://vivo.brown.edu/individual/org499605f7> a <http://vivoweb.org/ontology/core#College> ;
#     rdfs:label "School of Law" .
#
# <http://vivo.brown.edu/individual/org4c1f64aa> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Geology and Geophysics" .
#
# <http://vivo.brown.edu/individual/org4d01014a> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "History" .
#
# <http://vivo.brown.edu/individual/org4f9163cf> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Large Animal Clinical Sciences" .
#
# <http://vivo.brown.edu/individual/org52bbb58c> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Construction Science" .
#
# <http://vivo.brown.edu/individual/org533de40b> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Biology" .
#
# <http://vivo.brown.edu/individual/org58750032> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Teaching Learning and Culture" .
#
# <http://vivo.brown.edu/individual/org59444c74> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Physics and Astronomy" .
#
# <http://vivo.brown.edu/individual/org7048878f> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Engineering Technology and Industrial Distribution" .
#
# <http://vivo.brown.edu/individual/org7518c091> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Biomedical Engineering" .
#
# <http://vivo.brown.edu/individual/org8153433f> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Educational Administration and Human Resource Development" .
#
# <http://vivo.brown.edu/individual/org8b9df681> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Accounting" .
#
# <http://vivo.brown.edu/individual/org8e1497dc> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Marketing" .
#
# <http://vivo.brown.edu/individual/org90de7d78> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Industrial and Systems Engineering" .
#
# <http://vivo.brown.edu/individual/org91770559> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "English" .
#
# <http://vivo.brown.edu/individual/org94905f86> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Oceanography" .
#
# <http://vivo.brown.edu/individual/org9b0ead26> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Department of Communication" .
#
# <http://vivo.brown.edu/individual/org9e5eea38> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Sociology" .
#
# <http://vivo.brown.edu/individual/org9e87cc7b> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Political Science" .
#
# <http://vivo.brown.edu/individual/orga6291061> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Geography" .
#
# <http://vivo.brown.edu/individual/orga96ec482> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Civil Engineering" .
#
# <http://vivo.brown.edu/individual/orgac3e839c> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Computer Science" .
#
# <http://vivo.brown.edu/individual/orgc2b21c54> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Nuclear Engineering" .
#
# <http://vivo.brown.edu/individual/orge0412e57> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Recreation, Parks, and Tourism Science" .
#
# <http://vivo.brown.edu/individual/orge49738ce> a <http://vivoweb.org/ontology/core#College> ;
#     rdfs:label "Qatar Executive Management" .
#
# <http://vivo.brown.edu/individual/orge5c84f0a> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Aerospace Engineering" .
#
# <http://vivo.brown.edu/individual/orgea8f9be9> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Finance" .
#
# <http://vivo.brown.edu/individual/orgee598d70> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Statistics" .
#
# <http://vivo.brown.edu/individual/orgef68c136> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Health and Kinesiology" .
#
# <http://vivo.brown.edu/individual/orgf1153653> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Philosophy and Humanities" .
#
# <http://vivo.brown.edu/individual/orgf22c2cf7> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Small Animal Clinical Sciences" .
#
# <http://vivo.brown.edu/individual/orgf4046369> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Biochemistry and Biophysics" .
#
# <http://vivo.brown.edu/individual/orgf5352f2f> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Psychology" .
#
# <http://vivo.brown.edu/individual/orgf55b14ad> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Economics" .
#
# <http://vivo.brown.edu/individual/orgfb02a5ae> a <http://vivoweb.org/ontology/core#Department> ;
#     rdfs:label "Information and Operations Management" .
#
# <http://vivo.brown.edu/individual/orgfb6c9e2c> a <http://vivoweb.org/ontology/core#College> ;
#     rdfs:label "University Libraries" .

# %% [markdown]
# ##Positions
# We have all the tools we need to map the positions CSV to RDF but our process will be slightly different because we want to connect the people to their position and the position to its organization.

# %%
positions = read_file('data/positions.csv')
pprint(positions[:5])
# Out:
# [{'UID': u'2dec06e9',
#   'job_title': u'Professor',
#   'org_ID': u'8e1497dc',
#   'org_name': u'Marketing',
#   'position_type': u'Faculty'},
#  {'UID': u'c81ef444',
#   'job_title': u'Associate Professor',
#   'org_ID': u'f5352f2f',
#   'org_name': u'Psychology',
#   'position_type': u'Faculty'},
#  {'UID': u'5c2cef0e',
#   'job_title': u'Lecturer',
#   'org_ID': u'1ec41847',
#   'org_name': u'Mechanical Engineering',
#   'position_type': u'Faculty'},
#  {'UID': u'b6f25071',
#   'job_title': u'Clinical Associate Professor',
#   'org_ID': u'ef68c136',
#   'org_name': u'Health and Kinesiology',
#   'position_type': u'Faculty'},
#  {'UID': u'613870d1',
#   'job_title': u'Assistant Professor',
#   'org_ID': u'533de40b',
#   'org_name': u'Biology',
#   'position_type': u'Faculty'}]

# %% [markdown]
# ![ISF positions relations](https://wiki.duraspace.org/download/attachments/51052815/PeoplePositionsOrgs.2014-03-05.png?version=1&modificationDate=1395102709125&api=v2)
#
# See other VIVO-ISF relationship diagrams: https://wiki.duraspace.org/display/VIVO/VIVO-ISF+1.6+Relationship+Diagrams

# %%
#initialize an empty Graph
from utils import ns_mgr
g = Graph()
g.namespace_manager = ns_mgr

from rdflib import BNode

for pos in positions[:5]:
    position_uri = BNode()
    faculty_uri = D['fac{}'.format(pos['UID'])]
    org_uri = D['org{}'.format(pos['org_ID'])]
    g.add( (position_uri, RDF.type, VIVO.FacultyPosition) )
    g.add( (position_uri, RDFS.label, Literal(pos['job_title'])) )
    #Relate the position to the faculty member and organization.
    g.add( (position_uri, VIVO.relates, faculty_uri) )
    g.add( (position_uri, VIVO.relates, org_uri) )

print g.serialize(format='turtle')
# Out:
# @prefix bibo: <http://purl.org/ontology/bibo/> .
# @prefix obo: <http://purl.obolibrary.org/obo/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix vcard: <http://www.w3.org/2006/vcard/ns#> .
# @prefix vivo: <http://vivoweb.org/ontology/core#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# [] a vivo:FacultyPosition ;
#     rdfs:label "Professor" ;
#     vivo:relates <http://vivo.brown.edu/individual/fac2dec06e9>,
#         <http://vivo.brown.edu/individual/org8e1497dc> .
#
# [] a vivo:FacultyPosition ;
#     rdfs:label "Lecturer" ;
#     vivo:relates <http://vivo.brown.edu/individual/fac5c2cef0e>,
#         <http://vivo.brown.edu/individual/org1ec41847> .
#
# [] a vivo:FacultyPosition ;
#     rdfs:label "Assistant Professor" ;
#     vivo:relates <http://vivo.brown.edu/individual/fac613870d1>,
#         <http://vivo.brown.edu/individual/org533de40b> .
#
# [] a vivo:FacultyPosition ;
#     rdfs:label "Clinical Associate Professor" ;
#     vivo:relates <http://vivo.brown.edu/individual/facb6f25071>,
#         <http://vivo.brown.edu/individual/orgef68c136> .
#
# [] a vivo:FacultyPosition ;
#     rdfs:label "Associate Professor" ;
#     vivo:relates <http://vivo.brown.edu/individual/facc81ef444>,
#         <http://vivo.brown.edu/individual/orgf5352f2f> .

# %% [markdown]
# ## Creating URIs
# As you can see from both the raw position CSV and the output we don't have a unique identifier for the positions.  This is challenge you will often face when working with VIVO data.
#
# In the example code block above, we created [Blank Nodes](http://en.wikipedia.org/wiki/Blank_node) since these are "anonymous resources" but VIVO, and other triple stores, don't like Blank Nodes.
#
# One technique would be to create [URL Slugs](http://patterns.dataincubator.org/book/url-slug.html) based on uniquely identifying information.  This could lead to collisions - two resources being assigned the same URI - but that is not always a bad thing.  You can have separate routines that identify problematic data and flag it for human review.  For example, DbPedia uses this technique.  The URI for Harvard Universty is `http://dbpedia.org/resource/Harvard_University`.  This has worked well for organization names and even journal titles at Brown.  But in this example, a URL Slug would become too long.  So we will creaet
#
# Using standard Python libraries, we will mint a unique identifier for the position by creating an MD5 hash of the person id, organization id, and job title.  This isn't perfect (e.g. if the position title changes, a new URI and therefore a new position will be created) but is a good starting point.
#
# Here is the code above but the BNodes have been removed in favor of hash uris.

# %%
#initialize an empty Graph
from utils import ns_mgr, hash_uri
g = Graph()
g.namespace_manager = ns_mgr

from rdflib import BNode

for pos in positions[:5]:
    fac_id = pos['UID']
    org_id = pos['org_ID']
    title = pos['job_title']
    
    uri_parts = "{}{}{}".format(fac_id, org_id, title)
    position_uri = D[hash_uri(uri_parts, prefix='pos')]
    
    faculty_uri = D['fac{}'.format(fac_id)]
    org_uri = D['org{}'.format(org_id)]
    
    g.add( (position_uri, RDF.type, VIVO.FacultyPosition) )
    g.add( (position_uri, RDFS.label, Literal(title)) )
    #Relate the position to the faculty member and organization.
    g.add( (position_uri, VIVO.relates, faculty_uri) )
    g.add( (position_uri, VIVO.relates, org_uri) )

print g.serialize(format='turtle')
# Out:
# @prefix bibo: <http://purl.org/ontology/bibo/> .
# @prefix obo: <http://purl.obolibrary.org/obo/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix vcard: <http://www.w3.org/2006/vcard/ns#> .
# @prefix vivo: <http://vivoweb.org/ontology/core#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://vivo.brown.edu/individual/pos06b4b9643cb838ef3e287e0936926073> a vivo:FacultyPosition ;
#     rdfs:label "Associate Professor" ;
#     vivo:relates <http://vivo.brown.edu/individual/facc81ef444>,
#         <http://vivo.brown.edu/individual/orgf5352f2f> .
#
# <http://vivo.brown.edu/individual/pos0b047204de45965391cfaf37d8d2942b> a vivo:FacultyPosition ;
#     rdfs:label "Assistant Professor" ;
#     vivo:relates <http://vivo.brown.edu/individual/fac613870d1>,
#         <http://vivo.brown.edu/individual/org533de40b> .
#
# <http://vivo.brown.edu/individual/pos170fe58bf967ca7050f879cdbd96ff28> a vivo:FacultyPosition ;
#     rdfs:label "Professor" ;
#     vivo:relates <http://vivo.brown.edu/individual/fac2dec06e9>,
#         <http://vivo.brown.edu/individual/org8e1497dc> .
#
# <http://vivo.brown.edu/individual/pos4e325e1ec4fb651273b8a409f3ce636c> a vivo:FacultyPosition ;
#     rdfs:label "Clinical Associate Professor" ;
#     vivo:relates <http://vivo.brown.edu/individual/facb6f25071>,
#         <http://vivo.brown.edu/individual/orgef68c136> .
#
# <http://vivo.brown.edu/individual/pose9d67b0106879eb184e98335ab5ac419> a vivo:FacultyPosition ;
#     rdfs:label "Lecturer" ;
#     vivo:relates <http://vivo.brown.edu/individual/fac5c2cef0e>,
#         <http://vivo.brown.edu/individual/org1ec41847> .
